# %% [markdown]
# # Chapter 4. Determinants

# %% [markdown]
# $\Rightarrow n\times n $ Square matrix $detA$
#
# * Some important properties of $detA$
#
# 1) $A^{-1} exists　iffr　detA \neq 0$
#
# 2) $detA 　equals 　volume　of　 a 　box　 in 　\mathbb{R}^n$

# %% [markdown]
# ex)
#
# $a_1, a_2, a_3 　in 　\mathbb{R}^3$
#
# $A = [a_1 　a_2 　a_3] \rightarrow detA = Volume$
#
# $\int\int z(x,y)dxdy$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ex)
#
# Jachobian
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $\mathbb{R}^3:(x, y, z) \rightarrow (r, \theta, h)$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3) $detA$ = $I$(product of pivots): pivot들의 곱하기가 magnitude(vector의 크기)이다.

# %% [markdown]
# 4) Cramer's Rule
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4.2 Properties of Determinant
#
# * Consider 2$\times $2 matirx to make sure some basic properties
#
# $\Rightarrow $ expand to $n\times n$ matrix
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### $\bullet$ 3 Basic Properties
#
# 1) $detI = 1$
#
# 2) $detA$ changes the sign when two rows are interchanged
#
# ![image.png](data:image/png;base64,...)
#
# 3) $detA$ depends linearly on the first row
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4) If two rows are equal
#
# $\rightarrow detA=0$
#
# $pf)$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5) Row operations do not change the determinant
#
# Row operation : In $G\cdot E$, subtracting a multiple of one row from another row.
#
# $row1$ $-$ $l_{21}\cdot row2$ $\rightarrow$ $row1^{'}:new 　row1$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6) If $A$ has a zero-rows $
# \rightarrow detA=0$
#
# 7) If $A$ is triangular, $detA$= product of diagonal entries
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8) A: Singular $\rightarrow detA=0 \rightarrow A^{-1} not 　exist$
#
#
# 　　non-signualr $\rightarrow detA\neq 0\rightarrow A^{-1} exist$
#
# 9) $det(AB) = det(A)det(B)$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 10) $detA^T=detA$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4.3 Determinant formula

# %% [markdown]
# 1) $detA$ = product of all pivots from Gauss Elimination(=no pivoting)
#
# $A=LDU$
#
# $detA=detL(=1)detD(=\prod_{i=1}^np_i)detU(=1)$
#
# 2) $PA = LDU$(with some pivoting)
#
# $detP$ = $\pm1$
#
# $detA = \pm(\prod_{i=1}^nP_i)$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Basic Properties of determinant
#
# 1) $det I =1$
#
# 2) Row exchange $\rightarrow I$(sign change): 행을 한번 비꿀때 마다 부호가 바뀜
#
# 3) $detA$ depends linearly on the first row
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4) If a row is zero vector
#
# $detA=0$
#
# $detA = detA^T$
#
# $\Rightarrow $ if a column is zero vector, then $detA=0$
#
# $(a　b)^T=(a　0)^T+(0　b)^T$
#
# $(a　b　c)^T=(a　0　0)^T+(0　b　0)^T+(0　0　c)^T$
#
# 5) $detA$ depends linearly on the any rows
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ex)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ex)
#
# ![image.png](data:image/png;base64,...)
#
# ex)
#
# ![image.png](data:image/png;base64,...)
#
#
# $detA_n=2\cdot detA_{n-1}-detA_{n-2}$
#
# $detA \neq 0,　all 　pivots \neq 0$
#
# $A^{-1} exists$
#
# $A^{-1}b=X:특정한　solution이　unique하다$

# %% [markdown]
# # 4.4 Determinant Applications

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $A^{-1} = \frac{\mathbb{C}^T}{detA} \Rightarrow (detA)I=A\mathbb{C}^T$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ex)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2)
#
# $A$x=b
#
# $x=\begin{bmatrix}
# x_1  \\
# x_2 \\
# \vdots \\
# x_n
# \end{bmatrix} = A^{-1}b=A^{-1}\begin{bmatrix}
# b_1  \\
# b_2 \\
# \vdots \\
# b_n
# \end{bmatrix}$
#
# $x_i = \frac{detB_i}{detA},　　　B_i = \begin{bmatrix}a_1　a_2　\cdots　a_{i-1}　b　 a_{i+1}　\cdots　a_n\end{bmatrix},　b:　i_{th}　column$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3) Volume of Box
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * for all right angled box
#
# $|a_1| = l_1,　|a_2|=l_2,　\cdots $
#
# $a_i \perp a_j$
#
# $A=\begin{bmatrix}a_1　a_2　\cdots　a_n　\end{bmatrix}$
#
# $A^TA=\begin{bmatrix}a_1^T\\
# a_2^T \\
# \vdots \\
# a_n^T
# \end{bmatrix}\begin{bmatrix}a_1　a_2　\cdots  　a_n\end{bmatrix}=\begin{bmatrix}||a_1||^2 && 0 && 0 && \cdots && 0 && 0 \\
# 0 && ||a_2||^2　&& 0  && \cdots && 0 && 0 \\
# 0 && 0 && ||a_3||^2 && 0  && \cdots && 0 \\
# 0 && 0 && 0 && \ddots && 0 && 0 \\
# 0 && 0 && 0 && 0 && 0 && ||a_n||^2
# \end{bmatrix}$
#
# $detA = l_1l_2l_3\cdots l_n$

# %% [markdown]
# 3) Volume of Box
#
# * for non-right angled box
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $\int\int\int f(x, y, z)dxdydz \rightarrow drd\phi d\theta$
#
# ![image.png](data:image/png;base64,...)
