# %% [markdown]
# # Chapter 2 Vector Spaces

# %% [markdown]
# ## 2.1 Vector Spaces & Subspaces
#
# * space $\Rightarrow $ Set of closed under addition & scaler multiplication
#
# * For any vectors x, y $\in$ $R^T$
#
# * For any scaler $c \subset R$
#
# $\begin{cases}
# x+y \in U\\
# cx \in U
# \end{cases}$
#
# $c_1x+c_2y \in U(Vector Space)$
#
# 1) $x + y = x+y$
#
# 2) $x+(y+z) = (x+y)+z$
#
# 3) There is a zero-vector such that $X+\mathbb{0} = 0 + X = X$
#
# 4) For each vector $X$
#
# $X+)-X)=(-X)+X=0 　\Rightarrow -X 　unique$
#
# 5) $1\cdot X = X $
#
# 6) $C(x+y) = Cx + Cy$
#
# 7) $(C_1 + C_2)x =C_1x+C_2x$

# %% [markdown]
#  * Vector space(V)
#
# $\Rightarrow$ Set of vector in $R^n$
#
# 1) Closed under addition
#
# $$v_1 \in \mathbb{V}, 　v_2\in \mathbb{V}$$
#
# $$v_1+v_2\in \mathbb{V}$$
#
# 2) closed under scaler multiplicator
#
# $$v \in \mathbb{V},　c\in\mathbb{R},　cv \in \mathbb{V}$$
#
# 3) $\mathbb{V}$ includes the zero-vector(0)
#
# $$\mathbb{V} = \{0\}$$

# %% [markdown]
# * Column space of $A(\mathbb{C}(A))$
#
# $\Rightarrow $ Set of all linear combinations of column vectors in A
#
# $\{X|X=\sum_{i=1}^{n}c_1a_i\},　A=[a_1 　a_2 　\dots　a_n]$
#
# $AX = b, X =  \begin{bmatrix} x_1 \\ x_2\\ \vdots \\ x_n \end{bmatrix}$,
#
# then $x_1a_1+x_2a_2+\dots +x_na_n = \mathbb{b}$
#
# if $\mathbb{b} \in \mathbb{C}(A) \rightarrow $there are solutions,
#
# else if $\mathbb{b} \notin \mathbb{C}(A) \rightarrow$ no solution
#
# $A$x = $b$ : $A_{n\times n},　X=A^{-1}\mathbb{b}$
#
# $if 　A^{-1} 　exists,$
#
# always $\mathbb{b} \in \mathbb{C}(A), 　\mathbb{C}(A)$: whole space
#
# $A = \begin{bmatrix}
# 1 & -2 & 1 \\
# 2 & 1 & 1 \\
# 0 & 0 & 0
# \end{bmatrix} \Rightarrow $ 3차원 공간이지만 $z$성분들이 0임. 즉 모든 3차원 공간을 표현할 수 없음. 그러나 $A^{-1}$가 존재하면 3차원에서 어떠한 공간도 표현할 수 있다.
#
# $\Rightarrow$ whole space is constructed $a_1 \dots a_n$ by linear combinations $\rightarrow$ space

# %% [markdown]
# ------------------

# %% [markdown]
# #### Null space of $A(N(A))$
#
# $\Rightarrow$ Set of vectors and that $A$x=0
#
# $\rightarrow$ for more unknowns than equations
#
# $\mathbb{N}(A)=\{X|A$x$=0\}$
#
# 1) closed inder addition for $A\mathbb{x_1}=0,$  $A\mathbb{x_2}=0$
#
# $A(\mathbb{x_1}+\mathbb{x_2}) = 0 \rightarrow A\mathbb{x_1}+A\mathbb{x_2}=0+0=0$
#
# $\therefore \mathbb{x_1}+\mathbb{x_2} \in N(A)$
#
# 2) closed under scaler multiplication for $A\mathbb{x}=0$ for any $C$
#
# $\Rightarrow A(c\mathbb{x})=0$
#
# $cA\mathbb{x} = 0$
#
# $c\mathbb{x} \in N(A)$
#
# $
# \begin{cases}
# u+　　　　w=0 \cdots (1)\\
# 5u + 4v+9w = 0\cdots (2)\\
# 2u + 4v + 6w = 0\cdots (3)
# \end{cases}$
#
# (2) - 5$\times$(1) $\Rightarrow 4v+4w=0$
#
# (3) - 2$\times$(1) $\Rightarrow 4v+4w=0$
#
# $\therefore u+w=0$
#
# 　$v+w=0$
#
# $w=c$ 일때 $u=v=-c$ 이므로
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Solving Ax=0 & Ax=b
#
# ※ $A$x = b 형태와 회귀분석에서의 $X\beta = y$를 같은 꼴로 보아도 무관

# %% [markdown]
# $A$x = $0$
#
# ![image.png](data:image/png;base64,...)
#
# * m < n
#
# * $#$ of egns < $#$ of unknowns

# %% [markdown]
# ---

# %% [markdown]
# ### * Echelon form U
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# $u+3v-z=0$
#
# $w+z=0$
#
# pivot variable : $u,　w$
#
# free variable : $v, 　z$
#
# - pivot variable을 free variable로 표현
#
# $u = -3v+z$
#
# $w = -z$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### $A$x = b case
#
# b = $A$x=0 $\Rightarrow $ Null space $N(A)$
#
# ![image.png](data:image/png;base64,...)
#
# pivot에 대응되는 위치의 변수 : pivot variable $\rightarrow u,w$
#
# pivot에 위치에 속하지 않는 변수 : free variable $\rightarrow v, z$
#
# $u = -3v + z$
#
# $w = -z$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Ax=b($\neq0)$ case
#
# ![image.png](data:image/png;base64,...)
#
# 위에서 예로 든 b를 대입
#
# ![image.png](data:image/png;base64,...)
#
# $u+3v-z=-2$
#
# $w+z=1$
#
# 위 식을 통해 $u, v, w, z$를 구할 수 있음
#
# $\Rightarrow$결국 궁극적인 목적은 $u,v,w,z$를 구하는 것임

# %% [markdown]
# $u+3v-z=-2$　　$\Rightarrow$　$u=-3v+z-2$
#
# $w+z=1$　　　　　 $\Rightarrow$　$w=-z+1$
#
# ![image.png](data:image/png;base64,...)
#
# $A_x = A(X_n + X_p)$
#
# 　　$=A_{x_m}+A_{X_p} = b$

# %% [markdown]
# ---

# %% [markdown]
# ### Finding the solution $A$x=b
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 2.3 Linear Independence
#
# Basic (vectors) Dimension
#
# $\Rightarrow$ linear indepedent
#
# $c_1v_1 + c_2v_2 + \dots c_nv_n =0$ $\Leftrightarrow$  $c_1 = c_2 = \dots =
# c_n=0$
#
# $\Rightarrow$ Any Vector $v_k$ cannot be expressed by the other vectors
#
# ex)
#
# ![image.png](data:image/png;base64,...)
#
# ex) ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# * if G$\cdot$ E of A generates $m$ non-zero rows
#
# $\rightarrow$ m independent column vectors in A : None-zero인 row의 개수(=pivot이 있는 row의 개수)는 Indenpendent 개수와 같고 rank의 크기라고도 볼 수 있다.
#
# $\circ$ Rank of A
#
# = $#$ of independent column vectors
#
# = $#$ of independent row vectors
#
# = $#$ pivot in G$\cdot$E
#
# = Dim of $\mathbb{C}(A)$
#
# ex)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# * Spanning
#
#     * all linear combination of vectors $\{V_1　 V_2　\dots 　V_n\}$ construct a set of vector space
#
# = $\{V_1　 V_2　\dots 　V_n\}$　"span"　vector space
#
# ex)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# $\Rightarrow$ 모두 동일한 수평 영역에서의 평면이어도 기저벡터는 다를 수 있다.
#
# ![image.png](data:image/png;base64,...)
#
# * 위의 서로 linearly independent한 세 벡터 $v_1, v_2, v_3$들을 $R^3$공간에 표현하는 것을 "span"이라고 하며 이처럼 같은 공간이더라도 span하는 경우는 unique하지 않다. 그러나 만약 주어진 선형 독립 벡터들이 선형 결합을 이룰 경우 unique한 해가 존재한다.
#
# * If given linearly independent vectors are in linear combination $\Rightarrow$ unique

# %% [markdown]
# ### Basis(Vectors)
#
# $\Rightarrow$ minimum $#$ of vectors to span a vector space
#
# $\Rightarrow$ maximun $#$ of linearly independent vectors
#
# ![image.png](data:image/png;base64,...)
#
# $\Rightarrow$ not unique for a vector space
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Dimension of vector space
#
# = $#$ of linealy independent vectors
#
# * Rank(r) of A
#
# = $#$ of independent column vectors
#
# = $#$ of independent row vectors
#
# = $#$ of pivots in G$\cdot$E (Gauss Elimination )

# %% [markdown]
# ---

# %% [markdown]
# # 2.4  4 fundermental subspaces
#
# $A_{m\times n}$인 martix에 대해서
#
# 1) Column Space : $\mathbb{C}(A) \rightarrow$ linear combinations of colmn vectors: Its dimension is the rank r($\mathbb{R}^m)$
#
# 2) Null Space : $N(A) \{ X|A_x = 0\} \rightarrow$ Its dimension is n-r ($\subset \mathbb{R}^m) $
#
# 3) Row Space : $\mathbb{C}(A^T) \rightarrow $ linear combination of row vectors $( \subset \mathbb{R}^n)$
#
# 4) Left Null Space $N(A^T)　\{y|A^Ty=0\}$ $(\subset R^m)$
#
# ex)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# * 1)의 sub space dimension은 1차원이고($\because 행렬의 y값이 0)$ 4)의 sub space dimension도 1차원이다($\because 행렬의 x, z값이 0)$ 따라서 이 둘을 더해주게 되면
# 1)과 4)의 원래 차원인 2차원($\mathbb{R}^2$이 되는것을 볼 수 있다.
#
# * 마찬가지로 2)의 sub space dimension과 3)의 sub space dimension은 각 각 2와 1이고 이 둘을 더해주게 되면 이 둘의 원래 차원($\mathbb{R}^3$)인 3이 되는 것을 볼 수 있다.

# %% [markdown]
# * 또한 1)과 4)의 vector space들이 서로 수직이고, 마찬가지로 2)과 3)의 vector space도 서로 수직인것을 볼 수 있다.

# %% [markdown]
# * $A_{m\times n}$일때
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ex) 4 fundamental subspace 구하기
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 위에서 구한 sub space각각에 대하여 좌표상에 표현

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-100,100)
y_c = 3 * x
y_n = -2 * x
y_ct = 1/2 * x
y_nt = 1/-3 * x

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.axvline(x=0, color='black')
plt.axhline(y=0, color='black')
plt.plot(x, y_c, color='red')
plt.plot(x, y_nt, color='red')
plt.plot(x, y_n, color='blue')
plt.plot(x, y_ct, color='blue')
plt.xlim(-10, 10)
plt.ylim(-10, 10)
ax.set_aspect('equal', adjustable='box')
plt.show()

# %% [markdown]
# ### Existence of Inverse
#
# 1) square case
#
# $A^TA = AA^T = I$
#
# 2) $A_{m \times n}$,  $m<n \rightarrow$ Right Inverse
#
# 　　$A_{m\times n}A^{-1}_{n\times m} = I_{m \times m}$
#
# ![image.png](data:image/png;base64,...)
#
# 3) $A_{m\times n} ,  m>n$ $\rightarrow$  Left-Inverse
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $A$x=b
#
# if left-inverse
#
# $A^{-1}AX = A^{-1}b$
#
# $X = A^{-1}b$ $\rightarrow unique$
#
# else if right-inverse
#
# $AA^{-1}X = A^{-1}b$
#
# $X=A^{-1}b$ $\rightarrow not　unique$

# %% [markdown]
# ## 2.6 Linear Transformation

# %% [markdown]
# $A$x = b
#
# $System　equation,　x= solution$
#
# $\Rightarrow 　Linear　Combination of column vectors$
#
# $X \Rightarrow scaler　coefficients $

# %% [markdown]
# 　　　![image.png](data:image/png;base64,...)

# %% [markdown]
# $A　:　Linear　Transformation$
#
# $A_{m\times n}:　\mathbb{R}^n \rightarrow \mathbb{R}^m$
#
# $A(a_1$x$_1 + a_2$x$_2) = a_1A$x$_1+a_2A$x$_2$

# %% [markdown]
# Ex) 1)
#
# 　　　　![image.png](data:image/png;base64,...)
#
# 2)
#
# 　　　![image.png](data:image/png;base64,...)
#
# 3)
#
# 　　　![image.png](data:image/png;base64,...)

# %% [markdown]
# ex) differentiation $(\frac{d}{dt})$ of polynomial
#
# $x(t) 　=　a_0 +a_1t+a_2t^2 + \dots +a_nt^n$
#
# $y(t) = \frac{d}{dt}x(t) = b_0 + b1t+b_2t^2+\dots b_{n-1}t^{n-1}$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Null space $\rightarrow$ $A$x$ = b(=0)$를 만족하는 $X$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ex) integration$(\int_{-\infty}^{t}x(t)dt)$
#
# $A$x $=b$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ex) multiplication by a polynomial
#
# $x(t)\cdot p(t) = y(t)$
#
#
# $(a_1x_1(t)+a_2x_2(t))P(t)$
#
# $a_1x_1(t)P(t)+a_2(t)P(t)$
#
# $P(t) = P_0+P_1t+P_2t^2$
#
# $x(t) = a_0+a_1t+\cdots a_nt^n$
#
# $P(t) = b_0+b_1+\cdots b_n+2t^n+2$
#
# $\mathbb{R}^{n+1}\rightarrow \mathbb{R}^{n+3}$

# %% [markdown]
# * If given $A$x for every basis vectors $X$
#
# $A$x$_1$=$a_1$,  　$A$x$_2$=$a_2$,　$\cdots$ 　,$A$x$_n$=$a_n$
#
# then we can find any transform results in th space without $A$
#
# $\rightarrow y = C_1$x$_1+C_2$x$_2+\cdots C_n$x$_n$
#
# 　$Ay = C_1A$x$_1+C_2A_2$x$_2+\cdots+C_nA$x$_n$
#
# 　　  $= C_1a_1+C_2a_2+\cdots +C_na_n$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Basis Vectors
#
# $X_1$ $\rightarrow$ $a_1$
#
# $X_2$ $\rightarrow$ $a_2$
#
# $X = \sum a_ix_i \rightarrow y=\sum C_ia_i$

# %% [markdown]
# * How to find A?
#
# $\Rightarrow$ if we know the $A$x for the elementary basis vectors

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $A = [a_1　 a_2　 \cdots 　a_n ]$
#
# ex)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * for different basis vectors
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (1) polynomial differentiation
#
# $x(t) = a_0 +a_1t + a_2t^2+a_3t^3$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (2) polynomial integration $\int_{-\infty}^{t}x(t)df$
#
# $x(t) = a_0+a_1t+a_2t^2+a_3t^3$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $R_\theta R_\phi = R_{\theta + \phi}$
#
# $R_\theta R_\theta = R_2\theta , R_\theta R_\theta = I$
#
# $detR_\theta =1, R_\theta^{-1}=R_{-\theta}$

# %% [markdown]
# 2) Projection onto $\theta-line$
