# %% [markdown]
# # Chapter 3 Orthogonality

# %% [markdown]
# ## 3.1 Orthogonality vectors & subspace
#
# why orthogoniality vectors?
#
# $\rightarrow $ independent basis
#
# $\rightarrow$ easy calculation in linear combination

# %% [markdown]
# * length of vectors ||X||
#
# $\rightarrow ||X||^2 = X^TX=\sum_{i=1}^n x_i^2$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *By Pythagoras Theorem,
#
# $||y-x||^2 = ||X||^2+||y||^2$
#
# $(y-x)^T(y-x)=X^TX+y^Ty$
#
# $\Rightarrow y^Ty-y^TX-X^Ty+X^TX=X^TX+y^Ty$
#
# $X^Ty=y^TX, X^Ty=0$
#
# * for vector inner product
#
# 1) $X^Ty=0 \rightarrow angle=90^\circ$
#
# 2)$ X^Ty <0 \rightarrow angle > 90^\circ$
#
# 3) $X^Ty > 0 \rightarrow angle < 90^\circ$
#
# *If non-zero vectors  　$v_1,　v_2,　\cdots　,v_n$ are orthogonal,
#
# $v_i^Tv_j =0 ( i\neq j) , ||v_i||\neq0$
#
# $\rightarrow $then the vectors are linearly independent
#
# $C_1V_1+C_2V_2 + \cdots C_nV_n = 0$
#
# $\Rightarrow C_1=C_2=\cdots =C_n=0$
#
# $V_i^T(C_1V_1+C_2V_2+\cdots C_nV_n)=0$
#
# $C_i||V_i||^2=0$ for $\forall　i$
#
# $C_i = 0$
#
# $\Rightarrow orthogonal vectors \rightarrow basis vectors $
#
# $X = \sum_{i=1}^nC_iV_i, 　V_i^TX=C_i||V_i||^2$
#
# $orthonomal　 ||V_i||=1$

# %% [markdown]
# * Linearly indeoendent vectors
#
# $a_1, 　a_2,　\cdots　 a_n$
#
# $X = \sum_{i=1}^n C_1a_i$
#
# * Orthogonal subspace
#
# $\rightarrow $ Every vector in one subspace is orthogonal to every vector in the other subspace
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $A_{m\times n}$ 일때
#
# * Row Space $\perp$ Null Space
#
# $\mathbb{C}(A^T)$
#
# ![image.png](data:image/png;base64,...)
#
# $\sum_{k=1}^m C_ka_k \perp X$

# %% [markdown]
# * Column Space $\perp$ Left Null Space
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dim of VectorSpace = $#$ of independent vectors to span the VectorSpace
#
# 　　　　　　　　　=rank of A(r)
#
# Dim($\mathbb{C}(A))$ +Dim$N(A^T))$=m
#
# Dim($\mathbb{C}(A^T))$ +Dim$N(A))$=n

# %% [markdown]
# * Orthogonal (complelment) Subspace
#
# $v \in V, 　w\in W　in　 \mathbb{R}^N$
#
# $v \perp w　 \rightarrow orthogonal　subspace$
#
# $Dim(v)+Dim(w) = n$
#
# Orhogonal subspace $\neq$ orthogonal complement subspace

# %% [markdown]
# # 3.2 Cosines and Projections onto lines
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ex)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3.3 Projection and Least Squares
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Projection(P)의 성질
#
# 1) if $b \in \mathbb{C}(A) $
#
# 2) $P^2 = P$

# %% [markdown]
# ex)
#
# $ x-y$ planes , $b = \begin{bmatrix}
# 4 \\
# 5 \\
# 6
# \end{bmatrix}$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Least Square for line fitting
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $f(X) = (x-a_1)^2 + (x-a_2)^2+ \cdots +(x-a_n)^2$
#
# $minf(x) \Rightarrow x = \sum_{i=1}^n a_i :$ Least Square로 solution을 구하면 최적의 방정식은 평균으로 수렴한다.

# %% [markdown]
#  * 중간 정리

# %% [markdown]
# 1) Square System($A_{m\times n}, m \neq n) $

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $\Rightarrow G\cdot E : $ unique solution
#
# 　　$X = A^{-1} b$

# %% [markdown]
# 2) Underconstrained System$(A_{m \times n}, m<n)$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $\Rightarrow$ generally, infinitely many solutions
#
# $\Rightarrow X = X_n + X_p$
#
# $\Rightarrow$ how to find the solution
#
# $\rightarrow G\cdot E $ Reduce Raw Echelon Form
#
# $\rightarrow $ special solution (pivot variable / free variable)

# %% [markdown]
# 3) Overconstrained System($A_{m\times n} m>n$)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $\hat{X} = (A^TA)^{-1}A^Tb$
#
# $p = Pb = A(A^TA)^{-1}A^Tb$
#
# $\Rightarrow generally $ no solution
#
# $\Rightarrow min||AX-b||:Least Square$
#
# 점 b가 평면 밖에 있으므로 $A$x벡터와 b벡터 사이의 거리가 최소가 되는 값을 구함 이를 Least Square라 함

# %% [markdown]
# * Projection
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Orthogonal basis(vectors)
#
# $v_1, v_2, v_3, \dots v_n 　 ||v_i||=1$
#
# $v_i^Tv_j=0$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * If given independent vectors
#
# $a_1 , a_2, a_3, \cdots $
#
# $\rightarrow $ find the orthogonal basis vectors
#
# $\Rightarrow Gram 　Schmidt　 orthogonalization$

# %% [markdown]
# ### $\circ$ Gram Schmidt Orthogonalization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $a_1, a_2, \cdots $
#
# 1) $q_1 = \frac{a}{||a||}$
#
# 2) $a_j = \sum_{i=1}^{j-1}(q_i^Ta_j)q_i$
#
# 3) $A_j = q_j$

# %% [markdown]
# * Projection $\rightarrow $ Least Square
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Generalized Least Square
#
# $Ax = b 　X=\begin{bmatrix}
# x_1\\
# x_2\\
# \vdots \\
# x_n
# \end{bmatrix}$
#
# $\Rightarrow x_i \rightarrow w_i$
#
# $weight \Rightarrow probability$
#
# $WAX = Wb 　A^TW^TWAX=A^TW^Tb$
#
# ※ 통계적으로 봤을 때 W를 공분산이라 볼 수 있음

# %% [markdown]
# ## 3.4 Orthogonal Basis

# %% [markdown]
# * orthogonal vectors $\rightarrow$ independent
#
# * $Let q_1, q_2, \cdots q_n　 be　 orthonomal$
#
# $q_i^Tq_j=
# \begin{cases}
# 0, & \mbox{i $\neq$ j} \\
# 1, & \mbox{i=j}
# \end{cases}$
#
# Q = $\begin{bmatrix}
# q_1　 q_2 　q_3 　\cdots q_n
# \end{bmatrix}$
#
# $Q^TQ \Rightarrow Q^T=Q^{-1}(Left 　inverse)$
#
# =$\begin{bmatrix}
# q_1^T\\
# q_2^T\\
# \vdots\\
# q_n^T
# \end{bmatrix}\begin{bmatrix}
# q_1　 q_2 　q_3 　\cdots q_n
# \end{bmatrix} = I$

# %% [markdown]
# -----

# %% [markdown]
# * Q example
#
# 1) Rotation matrix
# $\begin{bmatrix}
# cos\theta && -sin\theta\\
# sin\theta && cos\theta
# \end{bmatrix}$
#
# 3) Permutation Matrix
#
# $\begin{bmatrix}
# 0 && 1 &&0 \\
# 1 && 0 && 0\\
# 0 && 0 && 1
# \end{bmatrix}$
#
# * Q transformation preserve the length and angle
#
# $\Rightarrow ||X||^2 = X^TX ||QX||^2 = X^TQ^TQX$
#
# $(QX)^T(Xy) = X^TQ^TQy = X^Ty$

# %% [markdown]
# ------

# %% [markdown]
# * Projection reduce the length : $||PX|| \le ||X||$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * for $q_1, q_2, \cdots q_n \in R^n$ (Square System)
#
# $\Rightarrow X = \sum_{i=1}^nc_iq_i$
#
# $X$ =  $\begin{bmatrix}
# q_1　 q_2 　q_3 　\cdots q_n
# \end{bmatrix}  \begin{bmatrix}
# c_1\\
# c_2\\
# \vdots\\
# c_n
# \end{bmatrix}$
#
# $\begin{bmatrix}
# c_1\\
# c_2\\
# \vdots\\
# c_n
# \end{bmatrix} = \begin{bmatrix}
# Q
# \end{bmatrix}^{-1}\begin{bmatrix}
# X
# \end{bmatrix} = Q^TX$
#
# $A\begin{bmatrix}
# c_1 \\
# c_2 \\
# \vdots\\
# c_n
# \end{bmatrix} = \begin{bmatrix}
# x_1 \\
# x_2 \\
# \vdots \\
# x_n
# \end{bmatrix},　　　　　Q\begin{bmatrix}
# c_1 \\
# c_2 \\
# \vdots \\
# c_n
# \end{bmatrix} = \begin{bmatrix}
# x_1 \\
# x_2 \\
# \vdots \\
# x_n
# \end{bmatrix}, 　　　　　　\begin{bmatrix}
# c_1 \\
# c_2 \\
# \vdots \\
# c_n
# \end{bmatrix} = Q^T\begin{bmatrix}
# x_1 \\
# x_@ \\
# \vdots \\
# x_n
# \end{bmatrix}$

# %% [markdown]
# $ = \begin{bmatrix}
# q_1^T \\
# q_2^T \\
# \vdots \\
# q_n^T
# \end{bmatrix}X$
#
# $c_i = \frac{q_i^TX}{q_i^Tq_i}$
#
# $X = \sum_{j=1}^{n}c_jq_j = \sum_{i=1}^n(q_i^TX)q_i$
#
# $q_i^TX = q_i^T(\sum_{j=1}^nc_jq_j)$
#
# 　　　$= q_i^T(c_1q_1+c_2q_2+\cdots +c_iq_i+c_nq_n)$
#
# 　　　$=c_i||q_i||^2=c_i$
#
# * for $q_1, q_2, \cdots , q_n \in (Rectangular　System)$
#
# $Q = \begin{bmatrix}
# q_1 　q_2 　\cdots　 q_n
# \end{bmatrix} 　　m<n $
#
# $Q$x = b
#
# $X = (Q^TQ)^{-1}Q^Tb$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Gram-Schmidt Orthogonalization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ex)
#
# $a_1 = \begin{bmatrix}
# 1 \\
# 0 \\
# 1
# \end{bmatrix}, 　　　　a_2 =\begin{bmatrix}
# 1 \\
# 0 \\
# 0
# \end{bmatrix}, 　　　　x_3=\begin{bmatrix}
# 2 \\
# 1 \\
# 0
# \end{bmatrix}$
#
# $q_1 = \frac{a_1}{||a_1||}=\frac{1}{\sqrt{2}}\begin{bmatrix}
# 1 \\
# 0 \\
# 1
# \end{bmatrix}$
#
# $q_2 = a_2 -(q_1^Ta_2)q_1=\begin{bmatrix}
# 1 \\
# 0 \\
# 0
# \end{bmatrix}-\frac{1}{\sqrt{2}}\begin{bmatrix}
# \frac{1}{\sqrt2} \\
# 0 \\
# \frac{1}{\sqrt2}
# \end{bmatrix} = \begin{bmatrix}
# \frac{1}{2} \\
# 0 \\
# -\frac{1}{2}
# \end{bmatrix} \rightarrow q_2=\frac{1}{\sqrt2}\begin{bmatrix}
# 1 \\
# 0 \\
# -1
# \end{bmatrix}$
#
# $q_3 : a_3-(q_1^Ta_3)q_1-(q_2^Ta_3)q_2$
#
# $\begin{bmatrix}
# 2 \\
# 1 \\
# 0
# \end{bmatrix}-\frac{1}{\sqrt2}-\sqrt2\begin{bmatrix}
# \frac{1}{\sqrt2} \\
# 0 \\
# -\frac{1}{\sqrt2}
# \end{bmatrix} = \begin{bmatrix}
# 0 \\
# 1 \\
# 0
# \end{bmatrix} = q_3$

# %% [markdown]
# * $A=QR$ factorization
#
# * from $G \cdot E \Rightarrow A=LU$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $A$x = b
#
# $X = (A^TA)^{-1}A^Tb$
#
# $=(R^TQ^TQR)^{-1}R^TQ^Tb$
#
# $=R^TRR^TQ^Tb$

# %% [markdown]
# ### Function Space(Hilbert) & Fourier Series

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Function Space(Hilbert Space)

# %% [markdown]
# $\Rightarrow $ expand vector space to functions
#
# $\Rightarrow $Vector Space $\in R^n \rightarrow Hilber 　Space \in R^\infty$
#
# $\Rightarrow x(t) + y(t) \in H$ 　$a \leq t \leq b$
#
# $x(t) + y(t) \in H$
#
# $\alpha x(t) \in H$
#
# $Vector :  V = (v_1, v_2, \cdots, v_n )^T$
#
# $\lim_{\Delta t\rightarrow\infty}x(t)=(x(a),x(a+\Delta t),x(a+2\Delta t), \cdots x(b))^T \rightarrow x(t) \in R^\infty$
#
# * Vector inner product $\rightarrow $ function inner product
#
# $X^Ty = \sum_{i=1}^nx_iy_i$　　　$(x(t),y(t))=\lim_{\Delta t\rightarrow 0}\sum_{k=0}^{\infty}x(a+k\Delta t)y(a+k \Delta t)$
#
# 　　　　　　　　　　　　　　　　　　$=\int_a^bx(t)y(t)dt$
#
# 　　　　　　　　　　　　　　　　　　$||x(t)||^2=\int_a^bx^2(t)dt$

# %% [markdown]
# * orthogonality
#
# $X^Ty=0　　　　(x(t), y(t) = \int_a^bx(t)y(t)dt=0$
#
# * Basis(vectors) $\rightarrow$ Basis(functions)
#
# $X = \sum_{i=1}^na_iv_i \rightarrow x(t) = \sum_{i=1}^\infty a_ib_i(t) : Series$
#
# $\sum_{i=1}^n(q_i^Ta)q_i \rightarrow \sum_{i=1}^\infty(q_i(t),x(t))q_i(t)$
#
# * If given a basis $\rightarrow$ linear combination {${a_i's}$} are unique
#
# * If given a basis (functions) $\rightarrow$ Series Coefficients {$a_i's$} are unique
#
# * espeically {$\cos nt, \sin mt$} m,n are integer $0\leq t \leq 2\pi $
#
# $n = m = 0 \Rightarrow DC성분$
#
# $frequency(주파수)$= $#$of ascilliation in a period($2\pi)$
#
# * orthogonal basis functions
#
# $\Rightarrow \int_0^{2\pi}\cos n_1t \cos n_2t$
#
# $\frac{1}{2}\int_o^{2\pi} \cos (n_1+n_2)t + \cos (n_1-n_2)t dt=0 　n_1\neq n_2$
#
# $\frac{1}{2}\int_0^{2\pi}(1+\cos 2nt)dt　　　　　　　　　　　　n_1 = n_2$
#
# $\Rightarrow \int \cos nt \sin mt dt \  0$
#
# 　　$\int sin m_1t \sin m_2t=\begin{cases}
# 0, & \mbox{$m_1 \neq m_2$} \\
# \pi, & \mbox{$m_1 = m_2$}
# \end{cases}$

# %% [markdown]
# * Fourier Series
#
# $\Rightarrow Basis functions \rightarrow \left\{ \cos,\sin \right\}$
# $0\leq t \leq 2\pi,　 n,m=integer$
#
# $x(t)=\sum_{n=0}^\infty a_n\cos nt + \sum_{m=1}^\infty b_n \sin mt$
#
# $e^{iwt} = \cos wt + j\sin wt$
#
# $x(t) = \sum_{k=1}^\infty a_k e^{jkt}$

# %% [markdown]
# #### Communication System
#
# $\Rightarrow Fourier　 Analysis$
#
# $\cos nt에서 　n:frequency$

# %% [markdown]
# * gram-Schmidt for functions
#
# $a_j-\sum_{i=1}^{j-1}(q_i^Ta_j)q_i 　\perp 　q_i(i=1, 2, \cdots j-1)$
#
# ex) $1, 　t,　t_2, 　t_3,　 \cdots　-1 \leq t \leq 1 $
#
# 1) $q_1(t)=1$
#
# 2) $t-(q_1(t),t)\cdot 1(=q_i(t))$
#
# 　$=t-\int_{-1}^1tdt\cdot1=t \rightarrow q_2(t)$
#
# 3) $t^2-(q_1(t)t^2)\cdot1$
#
# 　$-(q_2(t),t^2)\cdot q_2(t)$
#
# 　$=t^2-\int_{-1}^1t^2dt\cdot1 - \int_{-1}^1t^2tdt\cdot t$
#
# 　$=t^2-\frac{2}{3}$
